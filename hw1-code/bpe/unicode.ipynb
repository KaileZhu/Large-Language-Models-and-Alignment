# %% [markdown]
# 查看字符的 Unicode 编码：ord(char)

# %%
print(ord('北'))  # 输出: 21271
print(ord('大'))  # 输出: 22823
# Out:
# 21271
# 22823

# %% [markdown]
# 将 Unicode 编码转换为字符：chr(code)

# %%
print(chr(22823))  # 输出: 大
print(chr(27169))  # 输出: 模
print(chr(22411))  # 输出: 型
# Out:
# 大
# 模
# 型
